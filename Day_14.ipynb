# %% [markdown]
# # 21 Days Pyhton Challenge
# ## Day 14 🎃

# %%
value = 25
print(1 <= value <= 100)
# Out:
# True

# %%
email = 'user@example.com'
valid = '@' in email and '.' in email
print(valid)
# Out:
# True

# %%
password = 'python123'
if len(password) >= 8:
    print('Strong enough')
else:
    print('Too short')
# Out:
# Strong enough

# %%
numbers = [2, 4, 6, 8]
print(all(number % 2 == 0 for number in numbers))
# Out:
# True

# %%
numbers = [2, 4, 6, 8]
print(all(number % 2 == 0 for number in numbers))
# Out:
# True

# %%
def valid_age(age):
    return isinstance(age, int) and 0 <= age <= 120
print(valid_age(25), valid_age(-2))
# Out:
# True False

# %%
choices = ['yes', 'no']
answer = 'yes'
if answer.lower() in choices:
    print('Valid choice')
# Out:
# Valid choice

# %%
records = [{'name': 'Asha', 'score': 85}, {'name': 'Ravi', 'score': 72}]
for record in records:
    if 0 <= record['score'] <= 100:
        print(record['name'], 'valid')
# Out:
# Asha valid
# Ravi valid

# %%
number = 29
is_prime = number > 1
for divisor in range(2, number):
    if number % divisor == 0:
        is_prime = False
        break
print(is_prime)
# Out:
# True

# %%
required = ['name', 'email']
profile = {'name': 'Mira', 'email': 'mira@example.com'}
print(all(field in profile for field in required))
# Out:
# True
